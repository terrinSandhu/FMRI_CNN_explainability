# %%
import nibabel as nib
import numpy as np
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import glob
import os
import glob

# %%
def get_nii_files_glob(directory):
    # This will search for .nii files in the directory and all its subdirectories
    search_path = os.path.join(directory, '**', '*.nii')
    return glob.glob(search_path, recursive=True)

# %%
def get_nii_files_os(directory):
    nii_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.nii'):
                nii_files.append(os.path.join(root, file))
    return nii_files

# %%
# Function to load and preprocess .nii data
def load_nii_data(file_path):
    # Load the .nii file
    nii_data = nib.load(file_path)
    # Get the data as a numpy array
    data_array = nii_data.get_fdata()
    # Preprocess the data (e.g., normalization, reshaping)
    # ... your preprocessing steps here ...
    return data_array

# %%
# Load your .nii files (replace with your file paths)
file_paths = get_nii_files_os("C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35")
print(file_paths)
data = [load_nii_data(path) for path in file_paths]
print("d")
# Out:
# ['C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s008_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s009_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s011_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s014_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s021_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s022_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s025_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s028_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s030_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s034_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s035_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s036_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s037_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s040_anat.nii', 'C:/Users/tssan/OneDrive/Desktop/EngPsych/scans35\\s043_ana
# ...

# %%
# Flatten the data if necessary
flattened_data = [d.reshape(-1) for d in data]

# Combine all data into a single numpy array
combined_data = np.vstack(flattened_data)

# Apply PCA
pca = PCA(n_components=2)  # Adjust n_components as needed
pca_results = pca.fit_transform(flattened_data)
# Visualize the results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA visualization of .nii data')
plt.show()

# %%
# Apply PCA
pca = PCA(n_components=3)  # Adjust n_components as needed
pca_results = pca.fit_transform(combined_data)
# Visualize the results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA visualization of .nii data')
plt.show()

# %%
# Apply PCA
pca = PCA(n_components=1)  # Adjust n_components as needed
pca_results = pca.fit_transform(combined_data)
# Visualize the results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA visualization of .nii data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\tssan\OneDrive\Desktop\EngPsych\interp\pca.ipynb Cell 8 line <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/tssan/OneDrive/Desktop/EngPsych/interp/pca.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> pca_results = pca.fit_transform(combined_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/tssan/OneDrive/Desktop/EngPsych/interp/pca.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> # Visualize the results
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tssan/OneDrive/Desktop/EngPsych/interp/pca.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> plt.scatter(pca_results[:, 0], pca_results[:, 1])
#       <a href='vscode-notebook-cell:/c%3A/Users/tssan/OneDrive/Desktop/EngPsych/interp/pca.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> plt.xlabel('PCA Component 1')
# ...

# %%
# Apply PCA
pca = PCA(n_components=4)  # Adjust n_components as needed
pca_results = pca.fit_transform(combined_data)
# Visualize the results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA visualization of .nii data')
plt.show()

# %%
# Apply PCA
pca = PCA(n_components=5)  # Adjust n_components as needed
pca_results = pca.fit_transform(combined_data)
# Visualize the results
plt.scatter(pca_results[:, 0], pca_results[:, 1])
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA visualization of .nii data')
plt.show()
